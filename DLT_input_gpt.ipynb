# %%
pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import openai

# Set your API key
api_key = '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'
openai.api_key = api_key

# Read the text from your file
with open('/content/test_dlt.txt', 'r') as file:
    input_text = file.read()

# Define the prompt and get the response
prompt = f"Can you annotate the different parts of the following text and indicate the emotion of each part :\n{input_text}"
response = openai.Completion.create(
    engine="text-davinci-002",
    prompt=prompt,
    max_tokens=100  # You can adjust the max_tokens as needed
)

# Extract the generated response
output_text = response.choices[0].text

# Print or save the generated output
print(output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-3-9b8a77bb9a9d> in <cell line: 13>()
#      11 # Define the prompt and get the response
#      12 prompt = f"Can you annotate the different parts of the following text and indicate the emotion of each part :\n{input_text}"
# ---> 13 response = openai.Completion.create(
#      14     engine="text-davinci-002",
#      15     prompt=prompt,
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ...

# %%
import openai
import os

# Set OpenAI API key
openai.api_key = ""

# Then, you can call the "gpt-3.5-turbo" model
modelEngine = "gpt-3.5-turbo"

# set your input text
# inputText = "Write a 1,500 word that is highly speculative bullish article IN YOUR OWN WORDS on {} stock and why it went up, you must include how it could affect the stock price and future outcome of the business. Include subheadings in your own words and act like you know it all and be an authoritative expert on the topic. Now write."
inputText = "Write a 100 word tweet is highly speculative bullish article IN YOUR OWN WORDS on {} stock and why it went up, you must include how it could affect the stock price and future outcome of the business. Include subheadings in your own words and act like you know it all and be an authoritative expert on the topic. Now write."

# Array of keywords to generate article on
keywords = ["Nio (NIO)", "Apple (AAPL)", "Microsoft (MSFT)", "Tesla (TSLA)", "Meta (META)", "Amazon (AMZN)"]

# Switches and injects keywords into API request
for keyword in keywords:
    # set input text with the current keyword
    inputSent = inputText.format(keyword)

    # Send an API request and get a response, note that the interface and parameters have changed compared to the old model
    response = openai.ChatCompletion.create(
    model=modelEngine,
    messages=[{"role": "user", "content": inputSent }],
    n = 1
    )
    print("ChatGPT API replies for", keyword, "stock:\n")
    for choice in response.choices:
            #outputText = choice.text.strip()
            outputText = choice.message.content
            print(outputText)
            print("------")
    print("\n")

# %%
import json

json_string = '{"name": "John Doe", "age": 30, "email": "john@example.com"}'
data = json.loads(json_string)

with open('data.json', 'r') as file:
    data = json.load(file)

for fruit in data:
    print(fruit)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-11c166c697cc> in <cell line: 6>()
#       4 data = json.loads(json_string)
#       5
# ----> 6 with open('data', 'r') as file:
#       7     data = json.load(file)
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data'

# %% [markdown]
# my json file contains a persons name and a dialogue by the person ; and there are several such enteries. I want to give the chat gpt a group of such sentences let's say 10 at a time, and then ask the promt : "can you annotate the different parts of the following text and indicate the emotion of each sentence within the context?" using the chat gpt API

# %%
sentences = [
    "John: Hi there!",
    "Alice: How are you today?",
    "Bob: I'm feeling great!",
    "Eve: I had a rough day.",
    # Add more sentences here...
]

# %%
prompt = "Can you annotate the different parts of the following text and indicate the emotion of each sentence within the context?\n" + "\n".join(sentences)

# %%
import openai

# Set your API key
api_key = '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'
openai.api_key = api_key

# Create the user message
user_message = {"role": "system", "content": prompt}

# Make the API call
response = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[user_message],
)

# Extract the annotated and emotion information
annotated_text = response['choices'][0]['message']['content']

print(annotated_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-11-c29f20717c4b> in <cell line: 11>()
#       9
#      10 # Make the API call
# ---> 11 response = openai.ChatCompletion.create(
#      12     model="gpt-3.5-turbo",
#      13     messages=[user_message],
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/chat_completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# /usr/local/lib/python3.10/dist-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     153         )
#     154
# ...

# %%
user_message
# Out:
# {'role': 'system',
#  'content': "Can you annotate the different parts of the following text and indicate the emotion of each sentence within the context?\nJohn: Hi there!\nAlice: How are you today?\nBob: I'm feeling great!\nEve: I had a rough day."}

# %%
def extract_text_from_srt(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()

        subtitles = []
        current_subtitle = None

        for line in lines:
            line = line.strip()
            print(line)
            if line.isdigit():
                if current_subtitle:
                    subtitles.append(current_subtitle)
                current_subtitle = {'index': int(line), 'text': ''}
            elif line == '':
                if current_subtitle:
                    subtitles.append(current_subtitle)
                current_subtitle = None
            elif current_subtitle:
                current_subtitle['text'] += line + ' '

        if current_subtitle:
            subtitles.append(current_subtitle)

        extracted_text = [subtitle['text'].strip() for subtitle in subtitles]
        return extracted_text

    except FileNotFoundError:
        print(f"The file '{file_path}' does not exist.")
        return []
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        return []

# Example usage:
srt_file_path = '/content/friends.s02e01.720p.bluray.x264--sujaidr.srt'
extracted_text = extract_text_from_srt(srt_file_path)

for index, text in enumerate(extracted_text, start=1):
    print(f"Subtitle {index}:\n{text}\n")
# Out:
# ﻿1
# 00:00:00,267 --> 00:00:01,211
# Friends S02E01 The One With Ross's New Girlfriend (Celui qui a une nouvelle fiancée) (VO&VF+STFR&EN)
#
# 2
# 00:00:48,840 --> 00:00:52,051
# Flight number 457 from Beijing now arriving.
#
# 3
# 00:00:58,308 --> 00:01:01,477
# Oh, my God.
#
# 4
# 00:01:01,895 --> 00:01:05,397
# Oh, my... Excuse me. Move, move,
# move! Emergency, please!
#
# 5
# 00:01:05,607 --> 00:01:07,024
# Excuse me, excuse me.
#
# 6
# 00:01:13,865 --> 00:01:15,908
# - Rach!
# - Ah!
#
# 7
# 00:01:16,076 --> 00:01:17,534
# There you are!
#
# 8
# 00:01:17,702 --> 00:01:19,620
# Hey!
# - Hi!
#
# 9
# 00:01:19,829 --> 00:01:22,831
# Oh! So, so.
#
# 10
# 00:01:22,999 --> 00:01:25,793
# How was China? You!
#
# 11
# 00:01:26,419 --> 00:01:29,338
# It was... It was great.
# Oh, what happened?
#
# 12
# 00:01:29,506 --> 00:01:31,256
# - What? I am?
# - You're bleeding.
#
# 13
# 00:01:31,424 --> 00:01:33,050
# - God.
# - Oh, look at that! Yes, I am. Heh.
#
# 14
# ...

# %%
srt_file_path
# Out:
# '/content/test.srt'

# %%
# Example usage:
srt_file_path = '/content/friends.s02e01.720p.bluray.x264--sujaidr.srt'
extracted_text = extract_text_from_srt(srt_file_path)
# Out:
# An error occurred: 'utf-8' codec can't decode byte 0xc1 in position 4: invalid start byte

# %%
extracted_text
# Out:
# []

# %%
extracted_text[0].encode('utf-8').strip()
